# %%
import json

# %%
#load the data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("store_data.json")
print(data)
print(type(data))
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'great product!', 'age': '25'}, {'name': 'Bob', 'rating': '4', 'feedback': 'great product!', 'age': '20'}, {'name': 'Rutu', 'rating': '1', 'feedback': 'great product!', 'age': '19'}, {'name': 'Sona', 'rating': '3', 'feedback': 'great product!', 'age': '28'}, {'name': 'Alisha', 'rating': '0', 'feedback': 'great product!', 'age': '35'}]
# <class 'list'>

# %%
def clean_data(data):
    text_to_num = {
        "one": 1,
        "two": 2,
        "three": 3,
        "four": 4,
        "five": 5
    }

    cleaned_data = []
    unique_users = set()

    for user in data:

        # Clean ratings
        raw_rating = user["rating"].strip().lower()

        if raw_rating in text_to_num:
            raw_rating = text_to_num[raw_rating]

        user["rating"] = raw_rating

        # Handle missing age
        raw_age = user.get("age")

        if raw_age is None:
            user["age"] = None

        # Remove duplicate users
        name = user["name"].strip()

        if name in unique_users:
            continue

        unique_users.add(name)
        cleaned_data.append(user)

    return cleaned_data

# %%
clean_data(data)
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'great product!', 'age': '25'},
#  {'name': 'Bob', 'rating': '4', 'feedback': 'great product!', 'age': '20'},
#  {'name': 'Rutu', 'rating': '1', 'feedback': 'great product!', 'age': '19'},
#  {'name': 'Sona', 'rating': '3', 'feedback': 'great product!', 'age': '28'},
#  {'name': 'Alisha', 'rating': '0', 'feedback': 'great product!', 'age': '35'}]
