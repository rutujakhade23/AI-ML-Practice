# %%
import pandas as pd

# %%
info = {
    "name" : ["Rutu","Harshita", "Shradha"],
    "CGPA" : [8.76, 9.0, 9.8]
}
df = pd.DataFrame(info)

print(df)
# Out:
#        name  CGPA
# 0      Rutu  8.76
# 1  Harshita  9.00
# 2   Shradha  9.80

# %%
df
# Out:
#        name  CGPA
# 0      Rutu  8.76
# 1  Harshita  9.00
# 2   Shradha  9.80

# %%
s = pd.Series([1,2,3,4,5])
print(s)
print(type(s))

#index
print(s[0])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>
# 1

# %%
s = pd.Series([23, 24, 59, 90], index=["Rutuja","Eve", "Bob", "aai"])
print(s)
print(s["Eve"])
print(s.index)
# Out:
# Rutuja    23
# Eve       24
# Bob       59
# aai       90
# dtype: int64
# 24
# Index(['Rutuja', 'Eve', 'Bob', 'aai'], dtype='str')

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([1,2,3,4,5])
print(s1)
print(s2)
print(s1 + s2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
#dictionary 
info = {
    "Name" : ["Rutu", "Eve", "bob"],
    "Age" : [23,24,25],
    "GPA" : [9.5, 9.8, 10]
}

df = pd.DataFrame(info)
print(df, type(df))

print(df.index)
print(df.columns)
# Out:
#    Name  Age   GPA
# 0  Rutu   23   9.5
# 1   Eve   24   9.8
# 2   bob   25  10.0 <class 'pandas.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'GPA'], dtype='str')

# %%
df = pd.DataFrame([["Rutu", 23], ["Eve",24],["bob",25]], columns=["Name","Age"])
print(df)
# Out:
#    Name  Age
# 0  Rutu   23
# 1   Eve   24
# 2   bob   25

# %%
import numpy as np 
np_arr = np.array([[1,2,3],[4,5,6]])
df = pd.DataFrame(np_arr, columns=["A","B","C"])
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
#csv data
df = pd.read_csv("employee_data.csv")
print(df, type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
#Methods
print(df.head()) #starting 5 rows
print(df.tail())
print(df.sample(2))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000
#    ID    Name  Age Department  Salary
# 7   8  Hannah   26  Marketing   47000
# 9  10   Julia   30    Finance   60000

# %%
df.info
# Out:
# <bound method DataFrame.info of    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000>

# %%
df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %%
#openaq dataset
#openaq dataset
df = pd.read_csv("openaq.csv", delimiter=";")
df.head()
df.tail()
df.describe()
# Out:
#               Value
# count  4.345000e+04
# mean   7.663160e+02
# std    3.270961e+04
# min   -4.905140e+04
# 25%    1.600000e+00
# 50%    1.039900e+01
# 75%    3.684375e+01
# max    3.198676e+06

# %%
#Selection data

#columns 
df["City"]
df[["City","Location"]]

#rows
df.loc[0]
df.loc[0:2] #Start idx : end idx (inclusive)

df.iloc[0:2] #end idx : end idx (exclusive)

#cells - row, column
df.loc[4, ["City","Location"]]

df.iloc[0:3, 1:5]

df.at[0, "City"]

df["City"]
# Out:
# 0        Budapest Budatétény
# 1            Budapest Honvéd
# 2                   Budapest
# 3              Kazincbarcika
# 4             Székesfehérvár
#                 ...
# 43445                Kowloon
# 43446              Hong Kong
# 43447                    NaN
# 43448                    NaN
# 43449                    NaN
# Name: City, Length: 43450, dtype: str

# %%
#filtering the data
df[ df["Value"] > 100]
df.query("Value > 100 ")
# Out:
#       Country Code             City                        Location  \
# 1               HU  Budapest Honvéd                 Budapest Honvéd
# 4               HU   Székesfehérvár                  Székesfehérvár
# 11              IE      Dublin City                         IE0098A
# 35              IN              NaN  Sector- 16A, Faridabad - HSPCB
# 44              IN              NaN    Adarsh Nagar, Jaipur - RSPCB
# ...            ...              ...                             ...
# 43430           CN              NaN                             西园路
# 43434           CN              NaN                            市监测站
# 43440           CL        El Bosque                       El Bosque
# 43445           CN          Kowloon                        Mong Kok
# 43447           CN              NaN                              巨轮
#
#                               Coordinates Pollutant    Source Name   Unit  \
# 1                    47.522693, 19.069867        CO    hungary-nms  µg/m³
# 4                    47.195944, 18.400246        CO    hungary-nms  µg/m³
# 11                   53.341667, -6.288889        CO    EEA Ireland  µg/m³
# 35                 28.4088421, 77.3099081      PM10          caaqm  µg/m³
# 44          26.902908999999998, 75.836858     PM2.5          caaqm  µg/m³
# ...                                   ...       ...            ...    ...
# 43430        23.671400000000002, 116.6339        CO   ChinaAQIData  µg/m³
# 43434         30.6133, 105.68000000000002      PM10   ChinaAQIData  µg/m³
# 43440  -33.547099645619, -70.666204101852      PM10  Chile - SINCA  µg/m³
# 43445         22.3225, 114.16833333333334        CO      Hong Kong  µg/m³
# 43447                   37.8964, 112.5628        O3   ChinaAQIData  µg/m³
#
#        Value               Last Updated Country Label
# 1      289.0  2023-08-10T06:00:00+10:00       Hungary
# 4      237.0  2023-08-09T10:00:00+10:00       Hungary
# 11     370.0  2023-08-10T08:00:00+10:00       Ireland
# 35     634.0  2018-11-09T02:30:00+10:00         India
# 44     121.7  2022-10-31T12:00:00+10:00         India
# ...      ...                        ...           ...
# 43430  500.0  2021-01-01T02:00:00+10:00         China
# 43434  101.0  2021-01-01T02:00:00+10:00         China
# 43440  164.0  2023-08-10T08:00:00+10:00         Chile
# 43445  638.6  2023-08-10T10:00:00+10:00         China
# 43447  219.0  2021-08-09T21:00:00+10:00         China
#
# [5308 rows x 10 columns]

# %%
df
# Out:
#       Country Code                 City             Location  \
# 0               HU  Budapest Budatétény  Budapest Budatétény
# 1               HU      Budapest Honvéd      Budapest Honvéd
# 2               HU             Budapest              HU0045A
# 3               HU        Kazincbarcika        Kazincbarcika
# 4               HU       Székesfehérvár       Székesfehérvár
# ...            ...                  ...                  ...
# 43445           CN              Kowloon             Mong Kok
# 43446           CN            Hong Kong             Southern
# 43447           CN                  NaN                   巨轮
# 43448           CN                  NaN                   忠庄
# 43449           CN                  NaN                 马山宾馆
#
#                          Coordinates Pollutant   Source Name   Unit  \
# 0                  47.40605, 19.0099     PM2.5   hungary-nms  µg/m³
# 1               47.522693, 19.069867        CO   hungary-nms  µg/m³
# 2      47.4919433594653, 19.08778191       SO2   EEA Hungary  µg/m³
# 3       48.247032999999995, 20.61445      PM10   hungary-nms  µg/m³
# 4               47.195944, 18.400246        CO   hungary-nms  µg/m³
# ...                              ...       ...           ...    ...
# 43445    22.3225, 114.16833333333334        CO     Hong Kong  µg/m³
# 43446  22.247430000000005, 114.16015     PM2.5     Hong Kong  µg/m³
# 43447              37.8964, 112.5628        O3  ChinaAQIData  µg/m³
# 43448    27.6486, 106.89059999999999       NO2  ChinaAQIData  µg/m³
# 43449              30.5119, 117.0331       NO2  ChinaAQIData  µg/m³
#
#             Value               Last Updated Country Label
# 0        7.000000  2023-08-03T22:00:00+10:00       Hungary
# 1      289.000000  2023-08-10T06:00:00+10:00       Hungary
# 2        5.496181  2023-08-10T06:00:00+10:00       Hungary
# 3        6.000000  2023-08-09T10:00:00+10:00       Hungary
# 4      237.000000  2023-08-09T10:00:00+10:00       Hungary
# ...           ...                        ...           ...
# 43445  638.600000  2023-08-10T10:00:00+10:00         China
# 43446    5.400000  2023-08-10T10:00:00+10:00         China
# 43447  219.000000  2021-08-09T21:00:00+10:00         China
# 43448   16.000000  2021-08-09T21:00:00+10:00         China
# 43449   14.000000  2021-08-09T21:00:00+10:00         China
#
# [43450 rows x 10 columns]

# %%
#cleaning data - missing values 
df = pd.read_csv("raw_data.csv")
df.isnull()
df.isna()

df.isnull().sum()
df.dropna()  #row
df.dropna(axis=1) # col drop
df.fillna(0)
df.bfill()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#handle duplicate
df.duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
#data types
df.dtypes

df2 = df.copy()
df2 = df2.fillna(0)
df2 = df2["age"].astype("int64").copy()
df2.dtypes

df["gender"].str.lower()
df["name"].str.split(" ")
# Out:
# 0         [John, Doe]
# 1         [John, Doe]
# 2       [Jane, Smith]
# 3              [Alex]
# 4     [Maria, Garcia]
# 5           [Li, Wei]
# 6                 NaN
# 7       [Ahmed, Khan]
# 8       [Rachel, Lee]
# 9      [Carlos, Ruiz]
# 10     [Emily, Davis]
# Name: name, dtype: object

# %%
#feature engineering 
df2 = df.copy()
df2["tax"] = df2["income"].apply(lambda x : "20% " if x >= 50000 else "10%")


gender_map = {"Male" : "M", "Female" : "F", "Unknown" : "U"}
df2["gender"] = df2["gender"].map(gender_map)

#df2.columns = ["Id","Name","Age","Country","Gender","Income","Tax","New_Income"]

#df.rename(columns={"Income":"Salary"})
#df2.sort_values("Income")

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df2
# Out:
#     id          name   age country gender   income   tax
# 0    1      John Doe  29.0     USA      M  55000.0  20%
# 1    1      John Doe  29.0     USA      M  55000.0  20%
# 2    2    Jane Smith   NaN  Canada      F  62000.0  20%
# 3    3          Alex   NaN     USA      U  47000.0   10%
# 4    4  Maria Garcia  34.0   Spain      F      NaN   10%
# 5    5        Li Wei  27.0   China      M  51000.0  20%
# 6    6           NaN  45.0   India      F  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN      M  68000.0  20%
# 8    8    Rachel Lee  29.0     USA      F  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico      M  45000.0   10%
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%

# %%
df2 = df.copy()

new_col_order = [col for col in df2.columns if col != "id"] + ["id"]
print(new_col_order)
df2[new_col_order]
# Out:
# ['name', 'age', 'country', 'gender', 'income', 'id']
#             name   age country   gender   income  id
# 0       John Doe  29.0     USA     Male  55000.0   1
# 1       John Doe  29.0     USA     Male  55000.0   1
# 2     Jane Smith   NaN  Canada   Female  62000.0   2
# 3           Alex   NaN     USA  Unknown  47000.0   3
# 4   Maria Garcia  34.0   Spain   Female      NaN   4
# 5         Li Wei  27.0   China     Male  51000.0   5
# 6            NaN  45.0   India   Female  73000.0   6
# 7     Ahmed Khan  38.0     NaN     Male  68000.0   7
# 8     Rachel Lee  29.0     USA   Female  62000.0   8
# 9    Carlos Ruiz   NaN  Mexico     Male  45000.0   9
# 10   Emily Davis  31.0     USA      NaN  58000.0  10

# %%
df2 = df.copy()

df2 = df2.drop_duplicates()
df2.fillna(0)
df2 = df2.sort_values("income")
df2 = df2.reset_index(drop=True)
df2.to_csv("sorted_data.csv")

# %%
df2
# Out:
#    id          name   age country   gender   income
# 0   9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 1   3          Alex   NaN     USA  Unknown  47000.0
# 2   5        Li Wei  27.0   China     Male  51000.0
# 3   1      John Doe  29.0     USA     Male  55000.0
# 4  10   Emily Davis  31.0     USA      NaN  58000.0
# 5   2    Jane Smith   NaN  Canada   Female  62000.0
# 6   8    Rachel Lee  29.0     USA   Female  62000.0
# 7   7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8   6           NaN  45.0   India   Female  73000.0
# 9   4  Maria Garcia  34.0   Spain   Female      NaN

# %%
df.groupby("country")["income"].mean()
df.groupby("country")["income"].min()
df.groupby("country")["income"].max()
df.groupby("gender")["income"].mean()

df.groupby("country")["income"].agg(["mean", "min", "max"])
df.groupby("country")["income"].aggregate(["mean", "min", "max"])

df.groupby("country").agg({
    "income":"mean",
    "age": "mean"
})
df.groupby("country").agg(
    max_salary=("income","max"),
    avg_age=("age","mean")
)
# Out:
#          max_salary  avg_age
# country
# Canada      62000.0      NaN
# China       51000.0     27.0
# India       73000.0     45.0
# Mexico      45000.0      NaN
# Spain           NaN     34.0
# USA         62000.0     29.5

# %%
#melt and pivot
df = pd.DataFrame({
    "country":["USA","India","USA","India"],
    "year":[2020,2030, 2021,2023],
    "sales":[100,120,90,110],
    "profit":[20,25,18,22],
})

melted_df = df.melt(
    id_vars=["country","year"],
    value_vars=["sales","profit"],
    var_name="metrics",
    value_name="value"
)
melted_df.pivot(
    index=["country","year"],
    columns="metrics",
    values="value"
)
# Out:
# metrics       profit  sales
# country year
# India   2023      22    110
#         2030      25    120
# USA     2020      20    100
#         2021      18     90

# %%
melted_df
# Out:
#   country  year metrics  value
# 0     USA  2020   sales    100
# 1   India  2030   sales    120
# 2     USA  2021   sales     90
# 3   India  2023   sales    110
# 4     USA  2020  profit     20
# 5   India  2030  profit     25
# 6     USA  2021  profit     18
# 7   India  2023  profit     22

# %%
df
# Out:
#   country  year  sales  profit
# 0     USA  2020    100      20
# 1   India  2030    120      25
# 2     USA  2021     90      18
# 3   India  2023    110      22

# %%
df = pd.read_csv("employee_data.csv")
#df["Age"].hist()

#df.plot(kind="scatter",x="Age", y="Salary")

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df1 = pd.DataFrame({
    "id":[1,2,3],
    "name":["Adan","Eve","bob"]
})
df2 = pd.DataFrame({
    "id":[4,5,6],
    "name":["Charlie","rutu","swaraj"]
})
pd.concat([df1,df2]) #row
pd.concat([df1,df2], ignore_index=True)
pd.concat([df1, df2], axis=1) #col
# Out:
#    id  name  id     name
# 0   1  Adan   4  Charlie
# 1   2   Eve   5     rutu
# 2   3   bob   6   swaraj

# %%
df1
# Out:
#    id  name
# 0   1  Adan
# 1   2   Eve
# 2   3   bob

# %%
df2
# Out:
#    id     name
# 0   4  Charlie
# 1   5     rutu
# 2   6   swaraj
